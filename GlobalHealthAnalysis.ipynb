# %%
import pandas as pd

# %%
import seaborn as sns

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('Global Health Statistics.csv')

# %%
data.head()
# Out:
#      Country  Year         Disease Name Disease Category  Prevalence Rate (%)  \
# 0      Italy  2013              Malaria      Respiratory                 0.95
# 1     France  2002                Ebola        Parasitic                12.46
# 2     Turkey  2015             COVID-19          Genetic                 0.91
# 3  Indonesia  2011  Parkinson's Disease       Autoimmune                 4.68
# 4      Italy  2013         Tuberculosis          Genetic                 0.83
#
#    Incidence Rate (%)  Mortality Rate (%) Age Group Gender  \
# 0                1.55                8.42      0-18   Male
# 1                8.63                8.75       61+   Male
# 2                2.35                6.22     36-60   Male
# 3                6.29                3.99      0-18  Other
# 4               13.59                7.01       61+   Male
#
#    Population Affected  ...  Hospital Beds per 1000  Treatment Type  \
# 0               471007  ...                    7.58      Medication
# 1               634318  ...                    5.11         Surgery
# 2               154878  ...                    3.49     Vaccination
# 3               446224  ...                    8.44         Surgery
# 4               472908  ...                    5.90      Medication
#
#    Average Treatment Cost (USD) Availability of Vaccines/Treatment  \
# 0                         21064                                 No
# 1                         47851                                Yes
# 2                         27834                                Yes
# 3                           144                                Yes
# 4                          8908                                Yes
#
#    Recovery Rate (%) DALYs  Improvement in 5 Years (%)  \
# 0              91.82  4493                        2.16
# 1              76.65  2366                        4.82
# 2              98.55    41                        5.81
# 3              67.35  3201                        2.22
# 4              50.06  2832                        6.93
#
#    Per Capita Income (USD)  Education Index  Urbanization Rate (%)
# 0                    16886             0.79                  86.02
# 1                    80639             0.74                  45.52
# 2                    12245             0.41                  40.20
# 3                    49336             0.49                  58.47
# 4                    47701             0.50                  48.14
#
# [5 rows x 22 columns]

# %%
data.tail()
# Out:
#              Country  Year         Disease Name Disease Category  \
# 999995  Saudi Arabia  2021  Parkinson's Disease       Infectious
# 999996  Saudi Arabia  2013              Malaria      Respiratory
# 999997           USA  2016                 Zika      Respiratory
# 999998       Nigeria  2020               Asthma          Chronic
# 999999     Indonesia  2004               Asthma     Neurological
#
#         Prevalence Rate (%)  Incidence Rate (%)  Mortality Rate (%) Age Group  \
# 999995                 4.56                4.83                9.65      0-18
# 999996                 0.26                1.76                0.56      0-18
# 999997                13.44               14.13                1.91     19-35
# 999998                 1.96               14.56                4.98       61+
# 999999                15.58                9.84                0.51     36-60
#
#         Gender  Population Affected  ...  Hospital Beds per 1000  \
# 999995  Female               119332  ...                    4.23
# 999996  Female               354927  ...                    6.34
# 999997   Other               807915  ...                    8.11
# 999998  Female               385896  ...                    6.91
# 999999   Other               632775  ...                    6.79
#
#         Treatment Type  Average Treatment Cost (USD)  \
# 999995     Vaccination                          4528
# 999996         Surgery                         20686
# 999997         Therapy                         18807
# 999998      Medication                         21033
# 999999         Therapy                           505
#
#        Availability of Vaccines/Treatment  Recovery Rate (%) DALYs  \
# 999995                                Yes              92.11  1024
# 999996                                 No              84.47   202
# 999997                                 No              86.81  3338
# 999998                                Yes              62.15  4806
# 999999                                Yes              77.23  3241
#
#         Improvement in 5 Years (%)  Per Capita Income (USD)  Education Index  \
# 999995                        3.88                    29335             0.75
# 999996                        7.95                    30752             0.47
# 999997                        7.31                    62897             0.72
# 999998                        3.82                    98189             0.51
# 999999                        1.11                    79640             0.42
#
#         Urbanization Rate (%)
# 999995                  27.94
# 999996                  77.66
# 999997                  46.90
# 999998                  34.73
# 999999                  78.51
#
# [5 rows x 22 columns]

# %%
data.size
# Out:
# 22000000

# %%
data.shape
# Out:
# (1000000, 22)

# %%
data.columns
# Out:
# Index(['Country', 'Year', 'Disease Name', 'Disease Category',
#        'Prevalence Rate (%)', 'Incidence Rate (%)', 'Mortality Rate (%)',
#        'Age Group', 'Gender', 'Population Affected', 'Healthcare Access (%)',
#        'Doctors per 1000', 'Hospital Beds per 1000', 'Treatment Type',
#        'Average Treatment Cost (USD)', 'Availability of Vaccines/Treatment',
#        'Recovery Rate (%)', 'DALYs', 'Improvement in 5 Years (%)',
#        'Per Capita Income (USD)', 'Education Index', 'Urbanization Rate (%)'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000000 entries, 0 to 999999
# Data columns (total 22 columns):
#  #   Column                              Non-Null Count    Dtype
# ---  ------                              --------------    -----
#  0   Country                             1000000 non-null  object
#  1   Year                                1000000 non-null  int64
#  2   Disease Name                        1000000 non-null  object
#  3   Disease Category                    1000000 non-null  object
#  4   Prevalence Rate (%)                 1000000 non-null  float64
#  5   Incidence Rate (%)                  1000000 non-null  float64
#  6   Mortality Rate (%)                  1000000 non-null  float64
#  7   Age Group                           1000000 non-null  object
#  8   Gender                              1000000 non-null  object
#  9   Population Affected                 1000000 non-null  int64
#  10  Healthcare Access (%)               1000000 non-null  float64
#  11  Doctors per 1000                    1000000 non-null  float64
#  12  Hospital Beds per 1000              1000000 non-null  float64
#  13  Treatment Type                      1000000 non-null  object
#  14  Average Treatment Cost (USD)        1000000 non-null  int64
#  15  Availability of Vaccines/Treatment  1000000 non-null  object
#  16  Recovery Rate (%)                   1000000 non-null  float64
#  17  DALYs                               1000000 non-null  int64
#  18  Improvement in 5 Years (%)          1000000 non-null  float64
#  19  Per Capita Income (USD)             1000000 non-null  int64
#  20  Education Index                     1000000 non-null  float64
#  21  Urbanization Rate (%)               1000000 non-null  float64
# dtypes: float64(10), int64(5), object(7)
# memory usage: 167.8+ MB

# %%
data.isnull().sum()
# Out:
# Country                               0
# Year                                  0
# Disease Name                          0
# Disease Category                      0
# Prevalence Rate (%)                   0
# Incidence Rate (%)                    0
# Mortality Rate (%)                    0
# Age Group                             0
# Gender                                0
# Population Affected                   0
# Healthcare Access (%)                 0
# Doctors per 1000                      0
# Hospital Beds per 1000                0
# Treatment Type                        0
# Average Treatment Cost (USD)          0
# Availability of Vaccines/Treatment    0
# Recovery Rate (%)                     0
# DALYs                                 0
# Improvement in 5 Years (%)            0
# Per Capita Income (USD)               0
# Education Index                       0
# Urbanization Rate (%)                 0
# dtype: int64

# %%
data.dropna()
# Out:
#              Country  Year         Disease Name Disease Category  \
# 0              Italy  2013              Malaria      Respiratory
# 1             France  2002                Ebola        Parasitic
# 2             Turkey  2015             COVID-19          Genetic
# 3          Indonesia  2011  Parkinson's Disease       Autoimmune
# 4              Italy  2013         Tuberculosis          Genetic
# ...              ...   ...                  ...              ...
# 999995  Saudi Arabia  2021  Parkinson's Disease       Infectious
# 999996  Saudi Arabia  2013              Malaria      Respiratory
# 999997           USA  2016                 Zika      Respiratory
# 999998       Nigeria  2020               Asthma          Chronic
# 999999     Indonesia  2004               Asthma     Neurological
#
#         Prevalence Rate (%)  Incidence Rate (%)  Mortality Rate (%) Age Group  \
# 0                      0.95                1.55                8.42      0-18
# 1                     12.46                8.63                8.75       61+
# 2                      0.91                2.35                6.22     36-60
# 3                      4.68                6.29                3.99      0-18
# 4                      0.83               13.59                7.01       61+
# ...                     ...                 ...                 ...       ...
# 999995                 4.56                4.83                9.65      0-18
# 999996                 0.26                1.76                0.56      0-18
# 999997                13.44               14.13                1.91     19-35
# 999998                 1.96               14.56                4.98       61+
# 999999                15.58                9.84                0.51     36-60
#
#         Gender  Population Affected  ...  Hospital Beds per 1000  \
# 0         Male               471007  ...                    7.58
# 1         Male               634318  ...                    5.11
# 2         Male               154878  ...                    3.49
# 3        Other               446224  ...                    8.44
# 4         Male               472908  ...                    5.90
# ...        ...                  ...  ...                     ...
# 999995  Female               119332  ...                    4.23
# 999996  Female               354927  ...                    6.34
# 999997   Other               807915  ...                    8.11
# 999998  Female               385896  ...                    6.91
# 999999   Other               632775  ...                    6.79
#
#         Treatment Type  Average Treatment Cost (USD)  \
# 0           Medication                         21064
# 1              Surgery                         47851
# 2          Vaccination                         27834
# 3              Surgery                           144
# 4           Medication                          8908
# ...                ...                           ...
# 999995     Vaccination                          4528
# 999996         Surgery                         20686
# 999997         Therapy                         18807
# 999998      Medication                         21033
# 999999         Therapy                           505
#
#        Availability of Vaccines/Treatment  Recovery Rate (%) DALYs  \
# 0                                      No              91.82  4493
# 1                                     Yes              76.65  2366
# 2                                     Yes              98.55    41
# 3                                     Yes              67.35  3201
# 4                                     Yes              50.06  2832
# ...                                   ...                ...   ...
# 999995                                Yes              92.11  1024
# 999996                                 No              84.47   202
# 999997                                 No              86.81  3338
# 999998                                Yes              62.15  4806
# 999999                                Yes              77.23  3241
#
#         Improvement in 5 Years (%)  Per Capita Income (USD)  Education Index  \
# 0                             2.16                    16886             0.79
# 1                             4.82                    80639             0.74
# 2                             5.81                    12245             0.41
# 3                             2.22                    49336             0.49
# 4                             6.93                    47701             0.50
# ...                            ...                      ...              ...
# 999995                        3.88                    29335             0.75
# 999996                        7.95                    30752             0.47
# 999997                        7.31                    62897             0.72
# 999998                        3.82                    98189             0.51
# 999999                        1.11                    79640             0.42
#
#         Urbanization Rate (%)
# 0                       86.02
# 1                       45.52
# 2                       40.20
# 3                       58.47
# 4                       48.14
# ...                       ...
# 999995                  27.94
# 999996                  77.66
# 999997                  46.90
# 999998                  34.73
# 999999                  78.51
#
# [1000000 rows x 22 columns]

# %%
data.describe()
# Out:
#                  Year  Prevalence Rate (%)  Incidence Rate (%)  \
# count  1000000.000000       1000000.000000      1000000.000000
# mean      2011.996999            10.047992            7.555005
# std          7.217287             5.740189            4.298947
# min       2000.000000             0.100000            0.100000
# 25%       2006.000000             5.090000            3.840000
# 50%       2012.000000            10.040000            7.550000
# 75%       2018.000000            15.010000           11.280000
# max       2024.000000            20.000000           15.000000
#
#        Mortality Rate (%)  Population Affected  Healthcare Access (%)  \
# count      1000000.000000       1000000.000000         1000000.000000
# mean             5.049919        500735.427363              74.987835
# std              2.859427        288660.116648              14.436345
# min              0.100000          1000.000000              50.000000
# 25%              2.580000        250491.250000              62.470000
# 50%              5.050000        501041.000000              75.000000
# 75%              7.530000        750782.000000              87.490000
# max             10.000000       1000000.000000             100.000000
#
#        Doctors per 1000  Hospital Beds per 1000  Average Treatment Cost (USD)  \
# count    1000000.000000          1000000.000000                1000000.000000
# mean           2.747929                5.245931                  25010.313665
# std            1.299067                2.742865                  14402.279227
# min            0.500000                0.500000                    100.000000
# 25%            1.620000                2.870000                  12538.000000
# 50%            2.750000                5.240000                  24980.000000
# 75%            3.870000                7.620000                  37493.000000
# max            5.000000               10.000000                  50000.000000
#
#        Recovery Rate (%)           DALYs  Improvement in 5 Years (%)  \
# count     1000000.000000  1000000.000000              1000000.000000
# mean           74.496934     2499.144809                    5.002593
# std            14.155168     1443.923798                    2.888298
# min            50.000000        1.000000                    0.000000
# 25%            62.220000     1245.000000                    2.500000
# 50%            74.470000     2499.000000                    5.000000
# 75%            86.780000     3750.000000                    7.510000
# max            99.000000     5000.000000                   10.000000
#
#        Per Capita Income (USD)  Education Index  Urbanization Rate (%)
# count           1000000.000000   1000000.000000         1000000.000000
# mean              50311.099835         0.650069              54.985212
# std               28726.959359         0.144472              20.214042
# min                 500.000000         0.400000              20.000000
# 25%               25457.000000         0.530000              37.470000
# 50%               50372.000000         0.650000              54.980000
# 75%               75195.000000         0.780000              72.510000
# max              100000.000000         0.900000              90.000000

# %%
gender_disparity = data.groupby(['Disease Category', 'Gender']).sum(numeric_only=True).reset_index()

# %%
gender_diff = gender_disparity.pivot(index='Disease Category', columns='Gender', values=['Prevalence Rate (%)', 'Incidence Rate (%)', 'Mortality Rate (%)', 'DALYs'])

# %%
gender_diff.columns = ['_'.join(col).strip() for col in gender_diff.columns.values]

# %%
gender_diff = gender_diff.rename(columns={
    'Prevalence_Male': 'Prevalence_Male', 
    'Prevalence_Female': 'Prevalence_Female',
    'Incidence_Male': 'Incidence_Male',
    'Incidence_Female': 'Incidence_Female',
    'Mortality_Male': 'Mortality_Male',
    'Mortality_Female': 'Mortality_Female',
    'DALYs_Male': 'DALYs_Male',
    'DALYs_Female': 'DALYs_Female'
})

# %%
gender_diff['DALYs_Difference'] = gender_diff['DALYs_Male'] - gender_diff['DALYs_Female']

# %%
top_diseases = data.groupby('Disease Category')['DALYs'].sum().sort_values(ascending=False).head(5)

# %%
# Plot 1: Gender disparities in DALYs
plt.figure(figsize=(10, 6))
gender_diff['DALYs_Difference'].sort_values().plot(kind='bar', color='teal')
plt.title('Gender Disparities in DALYs by Disease Category')
plt.ylabel('DALYs Difference (Male - Female)')
plt.xlabel('Disease Category')
plt.xticks(rotation=45)
plt.tight_layout()
plt.savefig('gender_disparities_dalys.png')  # Save plot as an image
plt.show()

# %%
# Plot 2: Top disease categories by total DALYs
plt.figure(figsize=(10, 6))
top_diseases.plot(kind='bar', color='coral')
plt.title('Top Disease Categories by Total DALYs')
plt.ylabel('Total DALYs')
plt.xlabel('Disease Category')
plt.xticks(rotation=45)
plt.tight_layout()
plt.savefig('top_disease_categories_dalys.png')  # Save plot as an image
plt.show()

# %%
# Plot 3: Line plot for DALYs trends (Line Plot)
plt.figure(figsize=(12, 6))
gender_diff[['DALYs_Male', 'DALYs_Female']].sort_values(by='DALYs_Male', ascending=False).plot(kind='line', marker='o')
plt.title('DALYs Trends for Male and Female Across Disease Categories')
plt.ylabel('DALYs')
plt.xlabel('Disease Category')
plt.xticks(rotation=45)
plt.tight_layout()
plt.savefig('dalys_trends_lineplot.png')  # Save plot as an image
plt.show()

# %%
# Plot 4: Distribution of DALYs (Box Plot)
plt.figure(figsize=(8, 6))
sns.boxplot(data=gender_diff[['DALYs_Male', 'DALYs_Female']], palette='Set2')
plt.title('Distribution of DALYs for Male and Female')
plt.ylabel('DALYs')
plt.xlabel('Gender')
plt.xticks([0, 1], ['Male', 'Female'])
plt.tight_layout()
plt.savefig('dalys_distribution_boxplot.png')  # Save plot as an image
plt.show()

# %%
dalys_distribution = data.groupby('Disease Category')['DALYs'].sum()

# %%
# Pie Chart: Distribution of Total DALYs by Disease Category
plt.figure(figsize=(8, 8))
dalys_distribution.plot(kind='pie', autopct='%1.1f%%', startangle=90, cmap='tab20')
plt.title('Distribution of Total DALYs by Disease Category')
plt.ylabel('')  # Remove y-axis label for aesthetics
plt.tight_layout()
plt.savefig('dalys_distribution_pie_chart.png')  # Save pie chart as an image
plt.show()

# %%
# Conclusion:
# 1. Gender disparities in DALYs are evident, with significant differences in disease impact between males and females. 
#    Certain diseases show a higher burden on males, while others affect females more prominently.
# 2. The top disease categories by DALYs highlight critical areas requiring focused health policies and interventions.
# 3. Correlation analysis between gender-specific metrics (Prevalence, Incidence, Mortality) indicates interconnected factors 
#    that can guide resource allocation and targeted strategies.
# 4. Visualizations provide a comprehensive understanding of trends and distributions, supporting data-driven decision-making in global health.

# %%
#Now We Are Gonna Explore The Case Of Health Status in any Nation  As Per The User's Choice of nation and gender
#Here, the User needs to enter the Nation and Gender
# the Query then analyses the Most sought After treatment options for devising future public health policy
#it also highlights the highly as well as the least incident disease Categories prevelant in that gender in that nation

# %%
data=data[['Country', 'Year', 
      #'Disease Name',
      'Disease Category',
       #'Prevalence Rate (%)',
      'Incidence Rate (%)',
      #'Mortality Rate (%)',
       #'Age Group',
      'Gender',
      #'Population Affected', 'Healthcare Access (%)',
       #'Doctors per 1000', 'Hospital Beds per 1000', 
      'Treatment Type',
       #'Average Treatment Cost (USD)', 'Availability of Vaccines/Treatment',
       #'Recovery Rate (%)', 'DALYs', 'Improvement in 5 Years (%)',
       #'Per Capita Income (USD)', 'Education Index', 'Urbanization Rate (%)'
     ]]

# %%
dat2=data.set_index('Country')

# %%
nat=input("please input the Country Name Here:")
# Out:
# please input the Country Name Here: Turkey

# %%
gend=input("please input gender here:")
# Out:
# please input gender here: Female

# %%
dattemp=dat2.loc[nat]

# %%
NationGendData=dattemp[dattemp['Gender'].str.contains(gend)].sort_values(by='Incidence Rate (%)',ascending=False)

# %%
NationGendData
# Out:
#          Year Disease Category  Incidence Rate (%)  Gender Treatment Type
# Country
# Turkey   2023       Autoimmune               15.00  Female     Medication
# Turkey   2013     Neurological               15.00  Female        Surgery
# Turkey   2024          Chronic               15.00  Female        Surgery
# Turkey   2018       Autoimmune               14.99  Female    Vaccination
# Turkey   2012     Neurological               14.99  Female     Medication
# ...       ...              ...                 ...     ...            ...
# Turkey   2019          Genetic                0.10  Female     Medication
# Turkey   2011          Genetic                0.10  Female    Vaccination
# Turkey   2009     Neurological                0.10  Female     Medication
# Turkey   2014        Bacterial                0.10  Female    Vaccination
# Turkey   2020      Respiratory                0.10  Female    Vaccination
#
# [16593 rows x 5 columns]

# %%
diseaseNationData=NationGendData.groupby('Disease Category')

# %%
diseaseNationData['Incidence Rate (%)'].mean()
# Out:
# Disease Category
# Autoimmune        7.215125
# Bacterial         7.377826
# Cardiovascular    7.688557
# Chronic           7.790992
# Genetic           7.497261
# Infectious        7.448651
# Metabolic         7.551262
# Neurological      7.629886
# Parasitic         7.503870
# Respiratory       7.632110
# Viral             7.630703
# Name: Incidence Rate (%), dtype: float64

# %%
y=diseaseNationData['Incidence Rate (%)'].mean().idxmax()

# %%
filtered_data = NationGendData[NationGendData['Disease Category'] ==y]

# Step 3: Find the most sought-after treatment type for this disease category
most_sought_treatment = filtered_data['Treatment Type'].value_counts().idxmax()

# %%
plt.figure(figsize=(16, 8), facecolor='lime')  
plt.title(f"Most Sought after Treatment Options for {gend}s Across Disease Categories in {nat}")

# Reduce the number of ticks if necessary and adjust label rotation and alignment
plt.xticks(rotation=45, ha='right', fontsize=12)

# Plot the data
diseaseNationData['Treatment Type'].value_counts().plot(kind="line", color='orange', linewidth=4, linestyle='--')

# Adjust the layout to prevent clipping
plt.tight_layout()  
plt.subplots_adjust(bottom=0.2)  # Increase bottom margin if labels are still getting cut off

# Show the plot
plt.show()

# %%
print(f"Maximum occuring disease category among {gend}s in {nat} is {y} Thus the most sought after treatment type is {most_sought_treatment} "  )
# Out:
# Maximum occuring disease category among Females in Turkey is Chronic Thus the most sought after treatment type is Vaccination

# %%
x=diseaseNationData['Incidence Rate (%)'].mean().idxmin()

# %%
filtered_data2 = NationGendData[NationGendData['Disease Category'] ==x]

# Step 3: Find the most sought-after treatment type for this disease category
most_sought_treatment2 = filtered_data2['Treatment Type'].value_counts().idxmin()

# %%
plt.figure(figsize=(12, 6),facecolor='pink')
plt.title(f"Trend Of Treatment Options Sought for {x} diseases in  {gend}s in {nat}")
plt.xticks(ticks=range(len(diseaseNationData['Disease Category'])),rotation=45, ha='right') 
plt.tight_layout()
filtered_data['Treatment Type'].value_counts().tail().plot(kind="line",color='green',linewidth=5, linestyle='--')
plt.show()

# %%
plt.figure(figsize=(8, 8),facecolor='yellow')
filtered_data2['Treatment Type'].value_counts().plot(kind='pie', autopct='%1.1f%%', startangle=90, cmap='tab20',pctdistance=0.85,labeldistance=1.05)
plt.title(f"Trend Of Treatment Options Sought for {x} diseases in  {gend}s in {nat}")
plt.ylabel('')  # Remove y-axis label for aesthetics

plt.tight_layout()
plt.savefig('treatment_pie_chart.png')  # Save pie chart as an image
plt.show()

# %%
print(f"Minimum occuring disease category among {gend}s in {nat} is {x} Thus the least sought after treatment type is {most_sought_treatment2} "  )
# Out:
# Minimum occuring disease category among Females in Turkey is Autoimmune Thus the least sought after treatment type is Therapy

# %%
plt.figure(figsize=(12, 6),facecolor='orange')
plt.title(f"Incidence Rate Trends for diseases in {gend}s Across Disease Categories in {nat}")
plt.ylabel(' Incidence Rate')
plt.xticks(ticks=range(len(diseaseNationData['Disease Category'])),rotation=45, ha='right') 

plt.tight_layout()
diseaseNationData['Incidence Rate (%)'].mean().plot(kind="line",color='red', linewidth=3, linestyle='--')
plt.show()

# %%
#Conclusion Of Query On Nation

# %%
print(f"Most prominent disease among {gend} in {nat} is {y} and its most sought treatment is {most_sought_treatment} ")
# Out:
# Most prominent disease among Female in Turkey is Chronic and its most sought treatment is Vaccination

# %%
print(f"Least prominent disease among {gend} in {nat} is {x} and its most sought treatment is {most_sought_treatment2} ")
# Out:
# Least prominent disease among Female in Turkey is Autoimmune and its most sought treatment is Therapy

# %%
# Conclusion:
# 1. Gender disparities in DALYs are evident, with significant differences in disease impact between males and females. 
#    Certain diseases show a higher burden on males, while others affect females more prominently.
# 2. The top disease categories by DALYs highlight critical areas requiring focused health policies and interventions.
# 3. Correlation analysis between gender-specific metrics (Prevalence, Incidence, Mortality) indicates interconnected factors 
#    that can guide resource allocation and targeted strategies.
# 4. Visualizations provide a comprehensive understanding of trends and distributions, supporting data-driven decision-making in global health.
